# %%
##introduction to matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot([1,2,3,4])

# %%
x=[1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y)

# %%
#method 1
fig=plt.figure()
ax=fig.add_subplot()
plt.show()

# %%
#method2
fig=plt.figure()
ax=fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
#method3 (what i use)
fid,ax=plt.subplots()
ax.plot(x,[50,100,150,200]);

# %%
type(fig),type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ##matplotlib example workfolw

# %%
import matplotlib.pyplot as plt

#1.prepare data
x = [1,2,3,4]
y = [11,22,33,44]

#2.setup
fig, ax=plt.subplots(figsize=(10,10))

#3plot data
ax.plot(x,y)

#4.customize plot
ax.set(title="simple plot",
      xlabel="x-axis",
      ylabel="y-axis")
# Out:
# [Text(0.5, 1.0, 'simple plot'), Text(0.5, 0, 'x-axis'), Text(0, 0.5, 'y-axis')]

# %% [markdown]
# # MAKING FIGURES WITH NUMPY ARRAYS
# ##we want
# -line plot
# -bar plot
# -scatter plt
# -histogram
# -subplots

# %%
x=np.linspace(1,10,100)
x[:10]
# Out:
# array([1.        , 1.09090909, 1.18181818, 1.27272727, 1.36363636,
#        1.45454545, 1.54545455, 1.63636364, 1.72727273, 1.81818182])

# %%
#plotting the data
fig,ax=plt.subplots()
ax.plot(x,x**2)

# %%
#scatter plots
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x))

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x))

# %%
#make a plot from dictionary
nut_butter_prices={"almond butter":10,
                  "peanut butter":8,
                  "cashew butter":12}
fig,ax=plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="adis nut butter store",
      ylabel="price")
# Out:
# [Text(0.5, 1.0, 'adis nut butter store'), Text(0, 0.5, 'price')]

# %%
fig,ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()),(nut_butter_prices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
#make some data for histogram
x = np.random.randn(1000)
fig,ax =plt.subplots()
ax.hist(x)
# Out:
# (array([  8.,  22.,  70., 152., 218., 214., 158., 104.,  42.,  12.]),
#  array([-3.10006887, -2.50737018, -1.91467149, -1.3219728 , -0.72927412,
#         -0.13657543,  0.45612326,  1.04882195,  1.64152064,  2.23421933,
#          2.82691802]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## two options for subplots

# %%
#subplot option1
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,5))

#plot for each different axes
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax4.hist(np.random.randn(1000))
# Out:
# (array([ 11.,  22.,  81., 148., 216., 234., 158., 104.,  20.,   6.]),
#  array([-3.03367687, -2.43649371, -1.83931056, -1.2421274 , -0.64494425,
#         -0.04776109,  0.54942206,  1.14660522,  1.74378838,  2.34097153,
#          2.93815469]),
#  <BarContainer object of 10 artists>)

# %%
#subplot option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10,5))
#plot to each different index
ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax[1,1].hist(np.random.randn(100))
# Out:
# (array([ 4.,  1., 16., 16., 18., 18., 12., 10.,  3.,  2.]),
#  array([-2.37442193, -1.85841464, -1.34240734, -0.82640004, -0.31039274,
#          0.20561456,  0.72162185,  1.23762915,  1.75363645,  2.26964375,
#          2.78565105]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## plotting from pandas dataframe

# %%
import pandas as pd

# %%
#make a dataframe
car_sales=pd.read_csv("car-sales (1).csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#from this website="https://pandas.pydata.org/docs/user_guide/visualization.html"
np.random.seed(123456)
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range("1/1/2023", periods=1000))
ts=ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
car_sales["sale-date"]=pd.date_range("1/1/2023",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  sale-date
# 0  Toyota  White         150043      4   $4,000.00 2023-01-01
# 1   Honda    Red          87899      4   $5,000.00 2023-01-02
# 2  Toyota   Blue          32549      3   $7,000.00 2023-01-03
# 3     BMW  Black          11179      5  $22,000.00 2023-01-04
# 4  Nissan  White         213095      4   $3,500.00 2023-01-05
# 5  Toyota  Green          99213      4   $4,500.00 2023-01-06
# 6   Honda   Blue          45698      4   $7,500.00 2023-01-07
# 7   Honda   Blue          54738      4   $7,000.00 2023-01-08
# 8  Toyota  White          60000      4   $6,250.00 2023-01-09
# 9  Nissan  White          31600      4   $9,700.00 2023-01-10

# %%
car_sales["total sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  sale-date  \
# 0  Toyota  White         150043      4   $4,000.00 2023-01-01
# 1   Honda    Red          87899      4   $5,000.00 2023-01-02
# 2  Toyota   Blue          32549      3   $7,000.00 2023-01-03
# 3     BMW  Black          11179      5  $22,000.00 2023-01-04
# 4  Nissan  White         213095      4   $3,500.00 2023-01-05
# 5  Toyota  Green          99213      4   $4,500.00 2023-01-06
# 6   Honda   Blue          45698      4   $7,500.00 2023-01-07
# 7   Honda   Blue          54738      4   $7,000.00 2023-01-08
# 8  Toyota  White          60000      4   $6,250.00 2023-01-09
# 9  Nissan  White          31600      4   $9,700.00 2023-01-10
#
#                                          total sales
# 0                                          $4,000.00
# 1                                 $4,000.00$5,000.00
# 2                        $4,000.00$5,000.00$7,000.00
# 3              $4,000.00$5,000.00$7,000.00$22,000.00
# 4     $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00
# 5  $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# 6  $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# 7  $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# 8  $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# 9  $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...

# %%
car_sales.plot();

# %%
#bar graph
x=np.random.randn(10,4)
x
# Out:
# array([[-2.18469514e-01, -6.16450925e-02, -7.23779508e-01,
#          5.51224563e-01],
#        [-4.97766894e-01,  8.37518504e-01,  1.10324469e+00,
#         -1.11838433e+00],
#        [-5.42980353e-01, -9.94001552e-01,  1.50874153e+00,
#         -3.28697042e-01],
#        [-5.62235360e-01,  1.59621423e-03,  7.75456738e-02,
#          9.89734049e-01],
#        [-1.69265447e+00,  4.73952131e-01, -6.89181704e-01,
#          5.98385361e-01],
#        [-1.75085584e-01,  1.04030132e+00,  9.89042902e-01,
#          1.62670373e+00],
#        [-1.64227473e+00, -8.37361636e-01, -2.89387809e-01,
#         -1.02054419e+00],
#        [ 5.89992859e-01,  1.39498128e+00,  3.43053668e-01,
#          6.95245592e-01],
#        [ 1.77251676e+00,  1.91212294e+00,  1.47836871e+00,
#          2.79344193e-01],
#        [-5.03901844e-02,  1.22743523e+00, -6.13171711e-01,
#          1.23756974e+00]])

# %%
#turn it into a dataframe
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.218470 -0.061645 -0.723780  0.551225
# 1 -0.497767  0.837519  1.103245 -1.118384
# 2 -0.542980 -0.994002  1.508742 -0.328697
# 3 -0.562235  0.001596  0.077546  0.989734
# 4 -1.692654  0.473952 -0.689182  0.598385
# 5 -0.175086  1.040301  0.989043  1.626704
# 6 -1.642275 -0.837362 -0.289388 -1.020544
# 7  0.589993  1.394981  0.343054  0.695246
# 8  1.772517  1.912123  1.478369  0.279344
# 9 -0.050390  1.227435 -0.613172  1.237570

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  sale-date  \
# 0  Toyota  White         150043      4   $4,000.00 2023-01-01
# 1   Honda    Red          87899      4   $5,000.00 2023-01-02
# 2  Toyota   Blue          32549      3   $7,000.00 2023-01-03
# 3     BMW  Black          11179      5  $22,000.00 2023-01-04
# 4  Nissan  White         213095      4   $3,500.00 2023-01-05
# 5  Toyota  Green          99213      4   $4,500.00 2023-01-06
# 6   Honda   Blue          45698      4   $7,500.00 2023-01-07
# 7   Honda   Blue          54738      4   $7,000.00 2023-01-08
# 8  Toyota  White          60000      4   $6,250.00 2023-01-09
# 9  Nissan  White          31600      4   $9,700.00 2023-01-10
#
#                                          total sales
# 0                                          $4,000.00
# 1                                 $4,000.00$5,000.00
# 2                        $4,000.00$5,000.00$7,000.00
# 3              $4,000.00$5,000.00$7,000.00$22,000.00
# 4     $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00
# 5  $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# 6  $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# 7  $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# 8  $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# 9  $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...

# %%
car_sales.plot(x="Make",y="Odometer (KM)", kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %%
#histogram
car_sales["Odometer (KM)"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=40)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#using another dataset
heart_disease=pd.read_csv("heart-disease.csv")
heart_disease[:5]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#histogram of age
heart_disease["age"].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease.plot.hist(figsize=(10,30),subplots=True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %% [markdown]
# # which one should we use (pyplot VS matplotlib oo method)
# * when plotting something quixkly,use pyplot method
# * when plotting something more advanced, use the OO method

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
over_50=heart_disease[heart_disease["age"]>50]
len(over_50)
# Out:
# 208

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
    #pyplot method
    over_50.plot(kind="scatter",
                x='age',
                 y='chol',
                c="target")
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
#OO method
fix,ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
                x='age',
                 y='chol',
                c="target",
            ax=ax)

#ax.set_xlim([45,100])
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
fix,ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
                x='age',
                 y='chol',
                c="target",
            ax=ax)

ax.set_xlim([45,100])
# Out:
# (45.0, 100.0)

# %%
#OO method from scratch(object oriented)
fig,ax = plt.subplots(figsize=(10,6))

#plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"])

#customizzing the plot
ax.set(title="heart diesease and cholestrol level",
      xlabel="age",
      ylabel="cholestrol")

#add a legend
ax.legend(*scatter.legend_elements(),title="Target")

#adding a horizoontal line
ax.axhline(over_50["chol"].mean(),
                  linestyle='--')

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#subplot of col,age,thalach
fig,(ax0,ax1)=plt.subplots(nrows=2,
                          ncols=1,
                          figsize=(10,10),sharex=True)

#add data to ax0
scatter =ax0.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"])

#xustomize to ax0
ax0.set(title="heart Disease and Cholestrol levels",
       
       ylabel="cholestrol")

#add a legend to ax0
ax0.legend(*scatter.legend_elements(),title="Target")

#adding a meanline
ax0.axhline(y=over_50["chol"].mean(),
                  linestyle='--')



#add data to ax1
scatter =ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"])

#xustomize to ax1
ax1.set(title="heart Disease and Cholestrol levels",
       xlabel="age",
       ylabel="thalach(max heart rate)")

#add a legend to ax1
ax1.legend(*scatter.legend_elements(),title="Target")

#adding a meanline
ax1.axhline(y=over_50["thalach"].mean(),
                  linestyle='--')

#add a title to the figure

fig.suptitle("Heart Disease Analysis", fontsize=16,fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ## customizing Matplotlib plots and getting stylish

# %%
#see the different styles avaliable
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
heart_disease["age"].plot()
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set seaborn style
sns.set_style("darkgrid")

# Your plotting code here
heart_disease["age"].plot()

# Show the plot
plt.show()

# %%
heart_disease.plot(x="age",y="thalach",kind='scatter')
# Out:
# <Axes: xlabel='age', ylabel='thalach'>

# %%
plt.style.use('ggplot')
heart_disease["age"].plot()
# Out:
# <Axes: >

# %%
#create some data
x=np.random.randn(10,4)
x
# Out:
# array([[-1.37678931,  0.86005416,  0.91305805, -1.06466958],
#        [-0.51910196,  1.51779823, -0.29136561, -0.51289966],
#        [ 1.088825  ,  1.44401338,  2.91833279,  0.01726972],
#        [-1.3264739 ,  0.87363841, -1.55623809, -1.07271442],
#        [ 1.19860993, -0.03024661,  0.28798604, -0.16796669],
#        [ 1.42015508, -0.44029844, -0.01522018, -0.45376078],
#        [ 0.79142578,  0.8957934 , -0.19616553,  0.38073321],
#        [-0.27587428,  1.40080981, -0.35647001,  0.79726805],
#        [-1.64304137,  1.04591122,  0.92451513,  1.55369306],
#        [ 0.39502294, -0.00709019, -1.6708305 , -0.48200159]])

# %%
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -1.376789  0.860054  0.913058 -1.064670
# 1 -0.519102  1.517798 -0.291366 -0.512900
# 2  1.088825  1.444013  2.918333  0.017270
# 3 -1.326474  0.873638 -1.556238 -1.072714
# 4  1.198610 -0.030247  0.287986 -0.167967
# 5  1.420155 -0.440298 -0.015220 -0.453761
# 6  0.791426  0.895793 -0.196166  0.380733
# 7 -0.275874  1.400810 -0.356470  0.797268
# 8 -1.643041  1.045911  0.924515  1.553693
# 9  0.395023 -0.007090 -1.670830 -0.482002

# %%
ax=df.plot(kind="bar")
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
#customize our plot with set()method
ax=df.plot(kind="bar")
#add some labels and a title
ax.set(title="random no bar graph from dataframe",
      xlabel="row number",
      ylabel="random number")
#make the legend visible
ax.legend().set_visible(True)
